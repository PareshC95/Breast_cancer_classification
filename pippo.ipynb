# %%
import pandas as pd

# %%
##Import data set

df = pd.read_csv("https://raw.githubusercontent.com/PareshC95/Breast_cancer_classification/refs/heads/main/data.csv")
##df = clean_dataframe(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.head(100)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# ..       ...       ...          ...           ...             ...        ...
# 95     86208         M       20.260         23.03          132.40     1264.0
# 96     86211         B       12.180         17.84           77.79      451.1
# 97    862261         B        9.787         19.94           62.11      294.5
# 98    862485         B       11.600         12.84           74.34      412.6
# 99    862548         M       14.420         19.77           94.48      642.5
#
# ...

# %%
print(df.to_string())
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# ...

# %%
import numpy as np
import pandas

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.shape
# Out:
# (569, 33)

# %%
subset = df[['diagnosis','radius_mean', 'radius_se', 'radius_worst']]

# %%
subset
# Out:
#     diagnosis  radius_mean  radius_se  radius_worst
# 0           M        17.99     1.0950        25.380
# 1           M        20.57     0.5435        24.990
# 2           M        19.69     0.7456        23.570
# 3           M        11.42     0.4956        14.910
# 4           M        20.29     0.7572        22.540
# ..        ...          ...        ...           ...
# 564         M        21.56     1.1760        25.450
# 565         M        20.13     0.7655        23.690
# 566         M        16.60     0.4564        18.980
# 567         M        20.60     0.7260        25.740
# 568         B         7.76     0.3857         9.456
#
# [569 rows x 4 columns]

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Load data
data = load_breast_cancer()
X = data.data
y = data.target

# Train model
model = DecisionTreeClassifier(random_state=42)
model.fit(X, y)

# Plot the tree
plt.figure(figsize=(50,10))
plot_tree(model,
          feature_names=data.feature_names,
          class_names=data.target_names,
          filled=True)
plt.show()

# %%
import seaborn as sns

# %%
#encode the values of diagnosis B and M to 0 and 1
df["diagnosis_enc"] = df["diagnosis"].map({'B': 0, 'M': 1})
df["diagnosis_enc"].value_counts()
# Out:
# diagnosis_enc
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df = df.drop(['id', 'diagnosis', 'Unnamed: 32'], axis=1)

# %%
X = df.drop('diagnosis_enc', axis=1)
y = df['diagnosis_enc']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
corr = X.corr()

plt.figure(figsize=(15, 13))
sns.heatmap(corr,
            cmap='coolwarm',
            center=0,
            # annot=True,
            # fmt=".2f",
            linecolor='white',
            linewidths=1
            )
blue_white = LinearSegmentedColormap.from_list("blue_white", ["blue", "white", "rebeccapurple"])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Calculate correlation matrix
corr = X.corr()

# Create a blue-white-rebeccapurple colormap
blue_white = LinearSegmentedColormap.from_list(["blue_white", "#2a508d", "#7ed957", "#ff914d"])

# Plot the heatmap
plt.figure(figsize=(15, 13))
sns.heatmap(corr,
            cmap=blue_white,
            center=0,
            linecolor='white',
            linewidths=1
            )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 9
#       6 corr = X.corr()
#       8 # Create a blue-white-rebeccapurple colormap
# ----> 9 blue_white = LinearSegmentedColormap.from_list(["blue_white", "#2a508d", "#7ed957", "#ff914d"])
#      11 # Plot the heatmap
#      12 plt.figure(figsize=(15, 13))
#
# TypeError: LinearSegmentedColormap.from_list() missing 1 required positional argument: 'colors'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Create a blue-white-blue diverging colormap
blue_white = LinearSegmentedColormap.from_list("blue_white", ["blue", "white", "rebeccapurple"])

sns.heatmap(corr,
            cmap=blue_white,
            center=0,
            linecolor='white',
            linewidths=1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Calculate correlation matrix
corr = X.corr()

# Create a custom colormap from a list of colors
blue_white = LinearSegmentedColormap.from_list(
    "custom_map",  # Name of the colormap
    ["#2a508d", "#7ed957", "#ff914d"]  # List of colors
)

# Plot the heatmap
plt.figure(figsize=(15, 13))
sns.heatmap(corr,
            cmap=blue_white,
            center=0,
            linecolor='white',
            linewidths=1
            )
plt.show()
